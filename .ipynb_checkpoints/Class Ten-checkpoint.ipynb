# %% [markdown]
# # Dataframes (contd.)

# %%
import pandas as pd

# %%
df = pd.read_csv("housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.shape
# Out:
# (20640, 10)

# %%
len(df)
# Out:
# 20640

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
df.tail(2)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20638          INLAND
# 20639          INLAND

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# ## Extracting Parts of the Dataframe

# %% [markdown]
# Extracting a single column from the dataframe.

# %%
df["ocean_proximity"]
# Out:
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY
#            ...
# 20635      INLAND
# 20636      INLAND
# 20637      INLAND
# 20638      INLAND
# 20639      INLAND
# Name: ocean_proximity, Length: 20640, dtype: object

# %%
type(df["ocean_proximity"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Extracting multiple columns...

# %%
df[["latitude", "longitude"]]
# Out:
#        latitude  longitude
# 0         37.88    -122.23
# 1         37.86    -122.22
# 2         37.85    -122.24
# 3         37.85    -122.25
# 4         37.85    -122.25
# ...         ...        ...
# 20635     39.48    -121.09
# 20636     39.49    -121.21
# 20637     39.43    -121.22
# 20638     39.43    -121.32
# 20639     39.37    -121.24
#
# [20640 rows x 2 columns]

# %%
df[0] # you tried extracting a row!
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-ad11118bc8f3> in <module>
# ----> 1 df[0]
#
# ...

# %% [markdown]
# The correct way to extract the row with index label 0

# %%
df.loc[0]
# Out:
# longitude              -122.23
# latitude                 37.88
# housing_median_age          41
# total_rooms                880
# total_bedrooms             129
# population                 322
# households                 126
# median_income           8.3252
# median_house_value      452600
# ocean_proximity       NEAR BAY
# Name: 0, dtype: object

# %%
df.loc[0, "ocean_proximity"]
# Out:
# 'NEAR BAY'

# %%
df.loc[0, ["total_rooms", "ocean_proximity"]]
# Out:
# total_rooms             880
# ocean_proximity    NEAR BAY
# Name: 0, dtype: object

# %%
df.loc[0:10, ["total_rooms", "ocean_proximity"]]
# Out:
#     total_rooms ocean_proximity
# 0         880.0        NEAR BAY
# 1        7099.0        NEAR BAY
# 2        1467.0        NEAR BAY
# 3        1274.0        NEAR BAY
# 4        1627.0        NEAR BAY
# 5         919.0        NEAR BAY
# 6        2535.0        NEAR BAY
# 7        3104.0        NEAR BAY
# 8        2555.0        NEAR BAY
# 9        3549.0        NEAR BAY
# 10       2202.0        NEAR BAY

# %%
df.loc[50:59, ["total_rooms", "population"]]
# Out:
#     total_rooms  population
# 50        896.0       735.0
# 51       1868.0      1061.0
# 52       3221.0      1959.0
# 53       1630.0      1162.0
# 54       1170.0       701.0
# 55        945.0       576.0
# 56       1238.0       622.0
# 57       1489.0       728.0
# 58       1387.0      1074.0
# 59        158.0        94.0

# %%
df.loc[[4,9,12], ["total_rooms", "population"]]
# Out:
#     total_rooms  population
# 4        1627.0       565.0
# 9        3549.0      1551.0
# 12       2491.0      1098.0

# %% [markdown]
# We can also treat our dataframe as a 2-d array.

# %%
df.iloc[39:44, 2:4]
# Out:
#     housing_median_age  total_rooms
# 39                52.0       2432.0
# 40                52.0       1665.0
# 41                51.0        936.0
# 42                49.0        713.0
# 43                52.0        950.0

# %% [markdown]
# ## Checking for Null Values in Our Data

# %%
df.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
df['total_bedrooms'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Name: total_bedrooms, Length: 20640, dtype: bool

# %% [markdown]
# True, internally is 1. False is 0. So sum of Trues and Falses = number of Trues.

# %%
df['total_bedrooms'].isnull().sum()
# Out:
# 207

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.isnull().sum() / len(df)
# Out:
# longitude             0.000000
# latitude              0.000000
# housing_median_age    0.000000
# total_rooms           0.000000
# total_bedrooms        0.010029
# population            0.000000
# households            0.000000
# median_income         0.000000
# median_house_value    0.000000
# ocean_proximity       0.000000
# dtype: float64

# %%
df.isnull().sum() / len(df) * 100
# Out:
# longitude             0.000000
# latitude              0.000000
# housing_median_age    0.000000
# total_rooms           0.000000
# total_bedrooms        1.002907
# population            0.000000
# households            0.000000
# median_income         0.000000
# median_house_value    0.000000
# ocean_proximity       0.000000
# dtype: float64

# %% [markdown]
# ## Handling Null Values

# %% [markdown]
# One possible option is to drop rows containing missing values.

# %%
df.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# By default, any method which changes our dataframe will return a copy of the changed dataframe keeping the original as it is. To change the frame itself, we supply an option called `inplace=True`

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (20433, 10)

# %%
df = pd.read_csv('housing.csv')

# %%
df.shape
# Out:
# (20640, 10)

# %% [markdown]
# We can throw away the column that has missing values.

# %%
df.dropna(axis=1, inplace=True)

# %%
df.shape
# Out:
# (20640, 9)

# %%
df = pd.read_csv('housing.csv')

# %% [markdown]
# Quickly comparing columns before and after.

# %%
df_cols_dropped = df.dropna(axis=1)

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df_cols_dropped.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'population', 'households', 'median_income', 'median_house_value',
#        'ocean_proximity'],
#       dtype='object')

# %%
set(df.columns) - set(df_cols_dropped.columns)
# Out:
# {'total_bedrooms'}

# %% [markdown]
# Filling missing values with something!

# %%
imputed_df = df.fillna(value=df['total_bedrooms'].mean())

# %%
imputed_df.shape
# Out:
# (20640, 10)

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
imputed_df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# Checking values and frequencies.

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
df['ocean_proximity'].nunique()
# Out:
# 5

# %% [markdown]
# ## Changing Column Names

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df.rename({
    "housing_median_age": "median_age_of_house"
}, axis=1)
# Out:
#        longitude  latitude  median_age_of_house  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                 41.0        880.0           129.0
# 1        -122.22     37.86                 21.0       7099.0          1106.0
# 2        -122.24     37.85                 52.0       1467.0           190.0
# 3        -122.25     37.85                 52.0       1274.0           235.0
# 4        -122.25     37.85                 52.0       1627.0           280.0
# ...          ...       ...                  ...          ...             ...
# 20635    -121.09     39.48                 25.0       1665.0           374.0
# 20636    -121.21     39.49                 18.0        697.0           150.0
# 20637    -121.22     39.43                 17.0       2254.0           485.0
# 20638    -121.32     39.43                 18.0       1860.0           409.0
# 20639    -121.24     39.37                 16.0       2785.0           616.0
#
# ...

# %%
df.rename({
    "housing_median_age": "median_age_of_house"
}, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'median_age_of_house', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df = pd.read_csv("housing.csv")

# %%
original_df = df.copy()

# %%
df.sort_values(by="total_rooms")
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3126     -117.79     35.21                 4.0          2.0             2.0
# 12286    -116.95     33.86                 1.0          6.0             2.0
# 16171    -122.50     37.79                52.0          8.0             1.0
# 5916     -118.44     34.28                46.0         11.0            11.0
# 73       -122.29     37.81                46.0         12.0             4.0
# ...          ...       ...                 ...          ...             ...
# 12201    -117.20     33.58                 2.0      30450.0          5033.0
# 6057     -117.78     34.03                 8.0      32054.0          5290.0
# 9880     -121.79     36.64                11.0      32627.0          6445.0
# 10309    -117.74     33.89                 4.0      37937.0          5471.0
# 13139    -121.44     38.43                 3.0      39320.0          6210.0
#
# ...

# %%
df.sort_values(by='total_rooms', ascending=False)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13139    -121.44     38.43                 3.0      39320.0          6210.0
# 10309    -117.74     33.89                 4.0      37937.0          5471.0
# 9880     -121.79     36.64                11.0      32627.0          6445.0
# 6057     -117.78     34.03                 8.0      32054.0          5290.0
# 12201    -117.20     33.58                 2.0      30450.0          5033.0
# ...          ...       ...                 ...          ...             ...
# 73       -122.29     37.81                46.0         12.0             4.0
# 5916     -118.44     34.28                46.0         11.0            11.0
# 16171    -122.50     37.79                52.0          8.0             1.0
# 12286    -116.95     33.86                 1.0          6.0             2.0
# 3126     -117.79     35.21                 4.0          2.0             2.0
#
# ...

# %%
df.sort_values(by=['ocean_proximity', 'total_bedrooms'])
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7125     -118.04     33.90                36.0         15.0             5.0
# 10654    -117.86     33.67                16.0         20.0             5.0
# 18504    -121.96     37.13                26.0         50.0             5.0
# 4492     -118.22     34.06                52.0         48.0             6.0
# 5342     -118.44     34.04                16.0         18.0             6.0
# ...          ...       ...                 ...          ...             ...
# 17041    -122.28     37.51                33.0       4719.0             NaN
# 17198    -119.75     34.45                 6.0       2864.0             NaN
# 17202    -119.73     34.44                38.0       1729.0             NaN
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
#
# ...

# %% [markdown]
# ## Group By

# %%
df = df.groupby(by='ocean_proximity')

# %%
import numpy as np

# %%
df.agg(np.mean)
# Out:
#                   longitude   latitude  housing_median_age  total_rooms  \
# ocean_proximity
# <1H OCEAN       -118.847766  34.560577           29.279225  2628.343586
# INLAND          -119.732990  36.731829           24.271867  2717.742787
# ISLAND          -118.354000  33.358000           42.400000  1574.600000
# NEAR BAY        -122.260694  37.801057           37.730131  2493.589520
# NEAR OCEAN      -119.332555  34.738439           29.347254  2583.700903
#
#                  total_bedrooms   population  households  median_income  \
# ocean_proximity
# <1H OCEAN            546.539185  1520.290499  517.744965       4.230682
# INLAND               533.881619  1391.046252  477.447565       3.208996
# ISLAND               420.400000   668.000000  276.600000       2.744420
# NEAR BAY             514.182819  1230.317467  488.616157       4.172885
# NEAR OCEAN           538.615677  1354.008653  501.244545       4.005785
#
#                  median_house_value
# ocean_proximity
# ...

# %%
df.agg(np.mean)['total_rooms']
# Out:
# ocean_proximity
# <1H OCEAN     2628.343586
# INLAND        2717.742787
# ISLAND        1574.600000
# NEAR BAY      2493.589520
# NEAR OCEAN    2583.700903
# Name: total_rooms, dtype: float64

# %%
df['total_rooms'].agg(np.mean)
# Out:
# ocean_proximity
# <1H OCEAN     2628.343586
# INLAND        2717.742787
# ISLAND        1574.600000
# NEAR BAY      2493.589520
# NEAR OCEAN    2583.700903
# Name: total_rooms, dtype: float64

# %% [markdown]
# # Column-wise Operations

# %%
df = original_df

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df['total_rooms'] / df['population']
# Out:
# 0        2.732919
# 1        2.956685
# 2        2.957661
# 3        2.283154
# 4        2.879646
#            ...
# 20635    1.970414
# 20636    1.957865
# 20637    2.238332
# 20638    2.510121
# 20639    2.007931
# Length: 20640, dtype: float64

# %%
df['rooms_per_person'] = df['total_rooms'] / df['population']

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity', 'rooms_per_person'],
#       dtype='object')

# %%
inland_df = df[df['ocean_proximity'] == 'INLAND']

# %%
inland_df.shape
# Out:
# (6551, 11)

# %%
df2 = df[(df['ocean_proximity'] == 'INLAND') & (df['population'] > 500)]

# %%
df2.shape
# Out:
# (5686, 11)

# %%
df3 = df[(df['ocean_proximity'] == 'INLAND') | (df['population'] > 500)]

# %%
df3.shape
# Out:
# (19525, 11)

# %%
a + b - c * d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-d7eecb56386c> in <module>
# ----> 1 a + b - c * d
#
# NameError: name 'a' is not defined
